# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = r'C:\Users\aashutosh\Downloads\titanic_ dataset_final.csv'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot(x='Survived',data=df)
plt.title('survival count')
plt.show()

# %%
import ollama
def generate_insights(df_summary):
    prompt = f'Analyze the dataset summary and provide insights:\n\n{df_summary}'
    response = ollama.chat(
         model = 'mistral',
         messages = [{'role':'user','content':prompt}]
    )
    return response['message'],['content']
summary = df.describe().to_string()

insights = generate_insights(summary)

print('\n AI-Generate insights:\n',insights)
# Out:
#  AI-Generate insights:
# ...

# %%
import ollama 
def generate_insights(def_summary):
    prompt = f'Analyze the dataset summary and provide insights\n\n{def_summary}'
    response = ollama.chat(
               model = 'mistral',
               message = [{'role':'user','content':promt}]
    )
    return response ['message']['content']

    summary = df.describe().to_string()
    insights = genrate_insights(summary)

print('this is the ai generated prompt',insights)
# Out:
# this is the ai generated prompt (Message(role='assistant', content=" The dataset provided appears to be the Titanic passenger data, which contains information about the passengers who boarded the Titanic on its maiden voyage in 1912. Let's break down some key insights from the summary statistics:\n\n1. PassengerId: It seems that every passenger has a unique ID ranging from 1 to 891. This column is likely used for identification purposes and may not provide much insight into the dataset, as it does not include any meaningful information about the passengers.\n\n2. Survived: The mean survival rate is 0.3838, indicating that only approximately 38.4% of passengers survived the disaster. This is a notable statistic that highlights the devastating impact of the sinking. The minimum value (0) indicates that no passengers with IDs less than or equal to 1 did not survive.\n\n3. Pclass: The Pclass column represents the passenger's ticket class, ranging from 1st (highest) to 3rd (lowest). The m
# ...

# %%
import ollama 
def generate_insights(df_summary):
    prompt = f'Analyze the summary and give the insights about that\n\n{summary}'
    response = ollama.chat(
               model = 'mistral',
               message = [{'role':'user','content':prompt}]
    )
    return response ['message']['content']

    summary = df.describe().to_string()
    insights = generate_insights(summary)
print('this is the ai generated summary',insights)
# Out:
# this is the ai generated summary (Message(role='assistant', content=" The dataset provided appears to be the Titanic passenger data, which contains information about the passengers who boarded the Titanic on its maiden voyage in 1912. Let's break down some key insights from the summary statistics:\n\n1. PassengerId: It seems that every passenger has a unique ID ranging from 1 to 891. This column is likely used for identification purposes and may not provide much insight into the dataset, as it does not include any meaningful information about the passengers.\n\n2. Survived: The mean survival rate is 0.3838, indicating that only approximately 38.4% of passengers survived the disaster. This is a notable statistic that highlights the devastating impact of the sinking. The minimum value (0) indicates that no passengers with IDs less than or equal to 1 did not survive.\n\n3. Pclass: The Pclass column represents the passenger's ticket class, ranging from 1st (highest) to 3rd (lowest). The 
# ...

# %%
import ollama
def generate_insights(df_summary):
    prompt = f'Analyze the summary and generate the insights\n\n{df_summary}'
    response = ollama.chat(
               model = 'mistral',
               messages = [{'role':'user','content':prompt}]
    )
    return response ['message']['content']

    summary = df.describe().to_string()
    insights = generate_insights(summary)

print('this is the ai generated summary',insights)
# Out:
# this is the ai generated summary (Message(role='assistant', content=" The dataset provided appears to be the Titanic passenger data, which contains information about the passengers who boarded the Titanic on its maiden voyage in 1912. Let's break down some key insights from the summary statistics:\n\n1. PassengerId: It seems that every passenger has a unique ID ranging from 1 to 891. This column is likely used for identification purposes and may not provide much insight into the dataset, as it does not include any meaningful information about the passengers.\n\n2. Survived: The mean survival rate is 0.3838, indicating that only approximately 38.4% of passengers survived the disaster. This is a notable statistic that highlights the devastating impact of the sinking. The minimum value (0) indicates that no passengers with IDs less than or equal to 1 did not survive.\n\n3. Pclass: The Pclass column represents the passenger's ticket class, ranging from 1st (highest) to 3rd (lowest). The 
# ...

# %%
import gradio as gr
def eda_analysis(file):
    df = pd.read_csv(file.name)
    summary = df.describe().to_string()
    insights = generate_insights(summary)
    return insights
demo = gr.Interface(fn=eda_analysis, inputs='file', outputs='text', title='ai powered eda with mistral')
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://4e6a928a842af72e0d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4e6a928a842af72e0d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "C:\Users\aashutosh\anaconda3\Lib\site-packages\gradio\queueing.py", line 667, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "C:\Users\aashutosh\anaconda3\Lib\site-packages\gradio\route_utils.py", line 349, in call_process_api
#     output = await app.get_blocks().process_api(
# ...

# %%
import gradio as gr 
def eda_analysis(file):
    df = pd.read_csv(file.name)
    summary = df.describe().to_string()
    insights = eda_analysis(summary)
    return insights

demo = gr.Interface(fn=eda_analysis, inputs='file',outputs='text', title='ai powered eda with mmistral')
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * Running on public URL: https://c8858c5dcd05463e89.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c8858c5dcd05463e89.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "C:\Users\aashutosh\anaconda3\Lib\site-packages\gradio\queueing.py", line 667, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "C:\Users\aashutosh\anaconda3\Lib\site-packages\gradio\route_utils.py", line 349, in call_process_api
#     output = await app.get_blocks().process_api(
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = pd.read_csv(r'C:\Users\aashutosh\Downloads\titanic_ dataset_final.csv')
df = pd.DataFrame(url)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import ollama

def generate_insights(df_summary):
    prompt = f'Analyze the summary of given dataset and generate the insights\n\n:{df_summary}'
    response = ollama.chat( model = 'mistral', messages = [{'role':'user','content':prompt}])
    return response ['message']['content']

summary = df.describe().to_string()
insights = generate_insights(summary)

print('the ai generated insights',insights)
# Out:
# the ai generated insights  The dataset provided is the famous Titanic dataset, which contains information about passengers who were on board the RMS Titanic during its maiden voyage in 14 April 1912. Let's analyze the insights from the given summary:
#
# 1. The count of rows in the dataset indicates that it includes 891 passengers.
#
# 2. Mean values:
#    - Survived: On average, only 0.3838 of the passengers survived the sinking of the Titanic (approximately 38.4%).
#    - Pclass: The average ticket class was 2.3086, indicating that most passengers were traveling in second-class cabins.
#    - Age: The average age was 29.6991 years old.
#    - SibSp: On average, each passenger had approximately 0.523 siblings or spouses aboard the ship.
#    - Parch: On average, passengers had about 0.3815 parents or children with them on board.
#    - Fare: The average ticket fare was $32.2042.
#
# ...

# %%
import gradio as gr
def eda_analysis(file):
    df = pd.read_csv(file.name)
    summary = df.descibe().to_string()
    insights = eda_analysis(summary)
    return insights

demo = gr.Interface(fn=eda_analysis, inputs='file',outputs='text', title='ai powered eda with mmistral')
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://b4c1716ae5efb735bb.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b4c1716ae5efb735bb.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = r'C:\Users\aashutosh\Downloads\titanic_ dataset_final.csv'

# %%
df = pd.read_csv(url)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot(x='Survived',data=df)
plt.title('survival count')
plt.show()

# %%
sns.countplot(x ='Survived', data = df)
plt.title('survival count')
plt.show()

# %%
import ollama 
def generate_insights(df_summary):
    prompt = f'Analyze the summary from the given dataset and generater insights\n\n:{df_summary}'
    response = ollama.chat( model = 'mistral' , messages = [{'role':'user','content':prompt}])
    return response ['message']['content']

summary = df.describe().to_string()
insights = generate_insights(summary)
print('this is the ai generated insights',insights)
# Out:
# this is the ai generated insights  The given dataset is the Titanic passenger data, where each row represents a passenger and columns provide various details about them such as their Passenger ID, Survived status (1 for survived, 0 otherwise), Pclass, Age, SibSp (number of siblings or spouses aboard the Titanic), Parch (number of parents or children aboard the Titanic), Fare (ticket price).
#
# Here are some insights derived from the summary:
#
# 1. Counts: The dataset consists of 891 records, with no missing values in any column.
#
# 2. Mean Values:
#    - Survived: The mean value is approximately 0.38, indicating that slightly less than half of the passengers survived.
#    - Pclass: The average Pclass is 2.3, suggesting most passengers were in Second Class or Steerage (Pclass 3).
#    - Age: The average age of passengers was 29.7 years old.
# ...

# %%
import gradio as gr
def eda_analysis(file):
    df = pd.read_csv(file.name)
    summary = df.describe().to_string()
    insights = generate_insights(summary)
    return insights

demo = gr.Interface(fn=eda_analysis, inputs='file' , outputs='text',title = 'ai powered mistral eda analysis')
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://d136348e4b597fc994.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d136348e4b597fc994.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
def eda_analysis(file):
    df = pd.read_csv(file.name)
    summary = df.describe().to_string()
    insights = generate_insights(summary)
    return insights

demo = gr.Interface(fn=eda_analysis, inputs='file', outputs='text' , title='ai powered insights')
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * Running on public URL: https://b9b13df6b219163ca8.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b9b13df6b219163ca8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = r'C:\Users\aashutosh\Downloads\titanic_ dataset_final.csv'

# %%
df = pd.read_csv(url)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import ollama
def generate_insights(df_summary):
    promt = f'Analyze the given dataset summary and generate insights\n\n:{df_summary}'
    response = ollama.chat( model =
