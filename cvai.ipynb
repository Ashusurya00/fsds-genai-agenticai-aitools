# %% [markdown]
# introduction to open cv and image processing

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\aashutosh\OneDrive\Desktop\fsds task completion\ghoda.jpg')

# %%
img
# Out:
# array([[[32, 20, 20],
#         [32, 20, 20],
#         [31, 19, 19],
#         ...,
#         [32, 33, 23],
#         [29, 30, 20],
#         [24, 25, 15]],
#
#        [[32, 20, 20],
#         [32, 20, 20],
#         [31, 19, 19],
#         ...,
#         [31, 32, 22],
#         [26, 27, 17],
#         [21, 22, 12]],
#
#        [[32, 20, 20],
#         [32, 20, 20],
#         [31, 19, 19],
#         ...,
#         [30, 31, 21],
#         [28, 29, 19],
#         [25, 26, 16]],
#
#        ...,
#
#        [[51, 65, 77],
#         [54, 68, 80],
#         [40, 53, 67],
#         ...,
#         [50, 60, 54],
#         [44, 51, 46],
#         [37, 44, 39]],
#
#        [[44, 58, 70],
#         [53, 67, 79],
#         [43, 56, 70],
#         ...,
#         [36, 46, 40],
#         [30, 37, 32],
#         [25, 32, 27]],
#
#        [[41, 55, 67],
#         [53, 67, 79],
#         [47, 60, 74],
#         ...,
#         [18, 28, 22],
#         [23, 30, 25],
#         [26, 33, 28]]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (148, 216, 3)

# %%
plt.imshow(img)

# %%
img
# Out:
# array([[[32, 20, 20],
#         [32, 20, 20],
#         [31, 19, 19],
#         ...,
#         [32, 33, 23],
#         [29, 30, 20],
#         [24, 25, 15]],
#
#        [[32, 20, 20],
#         [32, 20, 20],
#         [31, 19, 19],
#         ...,
#         [31, 32, 22],
#         [26, 27, 17],
#         [21, 22, 12]],
#
#        [[32, 20, 20],
#         [32, 20, 20],
#         [31, 19, 19],
#         ...,
#         [30, 31, 21],
#         [28, 29, 19],
#         [25, 26, 16]],
#
#        ...,
#
#        [[51, 65, 77],
#         [54, 68, 80],
#         [40, 53, 67],
#         ...,
#         [50, 60, 54],
#         [44, 51, 46],
#         [37, 44, 39]],
#
#        [[44, 58, 70],
#         [53, 67, 79],
#         [43, 56, 70],
#         ...,
#         [36, 46, 40],
#         [30, 37, 32],
#         [25, 32, 27]],
#
#        [[41, 55, 67],
#         [53, 67, 79],
#         [47, 60, 74],
#         ...,
#         [18, 28, 22],
#         [23, 30, 25],
#         [26, 33, 28]]], dtype=uint8)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[20, 20, 32],
#         [20, 20, 32],
#         [19, 19, 31],
#         ...,
#         [23, 33, 32],
#         [20, 30, 29],
#         [15, 25, 24]],
#
#        [[20, 20, 32],
#         [20, 20, 32],
#         [19, 19, 31],
#         ...,
#         [22, 32, 31],
#         [17, 27, 26],
#         [12, 22, 21]],
#
#        [[20, 20, 32],
#         [20, 20, 32],
#         [19, 19, 31],
#         ...,
#         [21, 31, 30],
#         [19, 29, 28],
#         [16, 26, 25]],
#
#        ...,
#
#        [[77, 65, 51],
#         [80, 68, 54],
#         [67, 53, 40],
#         ...,
#         [54, 60, 50],
#         [46, 51, 44],
#         [39, 44, 37]],
#
#        [[70, 58, 44],
#         [79, 67, 53],
#         [70, 56, 43],
#         ...,
#         [40, 46, 36],
#         [32, 37, 30],
#         [27, 32, 25]],
#
#        [[67, 55, 41],
#         [79, 67, 53],
#         [74, 60, 47],
#         ...,
#         [22, 28, 18],
#         [25, 30, 23],
#         [28, 33, 26]]], dtype=uint8)

# %%
fix_img.shape
# Out:
# (148, 216, 3)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\aashutosh\OneDrive\Desktop\fsds task completion\ghoda.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray
# Out:
# array([[21, 21, 20, ..., 30, 27, 22],
#        [21, 21, 20, ..., 29, 24, 19],
#        [21, 21, 20, ..., 28, 26, 23],
#        ...,
#        [67, 70, 56, ..., 57, 49, 42],
#        [60, 69, 59, ..., 43, 35, 30],
#        [57, 69, 63, ..., 25, 28, 31]], dtype=uint8)

# %%
img_gray.shape
# Out:
# (148, 216)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
plt.imshow(img_gray, cmap = 'Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (148, 216, 3)

# %%
fix_img_1=cv2.resize(fix_img,(70,108))

# %%
fix_img_1.shape
# Out:
# (108, 70, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0),fix_img, w_ratio,h_ratio)

# %%
fix_img_2
# Out:
# array([[[20, 20, 32],
#         [19, 19, 31],
#         [17, 17, 29],
#         ...,
#         [19, 29, 28],
#         [22, 32, 31],
#         [16, 26, 25]],
#
#        [[20, 20, 32],
#         [19, 19, 31],
#         [17, 17, 29],
#         ...,
#         [18, 28, 27],
#         [19, 29, 28],
#         [18, 28, 27]],
#
#        [[20, 20, 32],
#         [19, 19, 31],
#         [17, 17, 29],
#         ...,
#         [21, 31, 30],
#         [17, 27, 26],
#         [15, 25, 24]],
#
#        ...,
#
#        [[32, 35, 28],
#         [52, 55, 48],
#         [46, 48, 41],
#         ...,
#         [49, 53, 38],
#         [50, 53, 38],
#         [45, 47, 33]],
#
#        [[73, 63, 50],
#         [63, 51, 39],
#         [60, 46, 36],
#         ...,
#         [68, 71, 61],
#         [55, 60, 49],
#         [47, 51, 43]],
#
#        [[74, 62, 48],
#         [75, 61, 48],
#         [75, 58, 48],
#         ...,
#         [60, 63, 54],
#         [35, 41, 31],
#         [28, 33, 26]]], dtype=uint8)

# %%
plt.imshow(fix_img_2)

# %%
img3 = cv2.flip(fix_img_2,1)
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2,3)
plt.imshow(img3)

# %%
cv2.imwrite('new genai image.jpg',img3)
# Out:
# True

# %%
pwd
# Out:
# 'c:\\Users\\aashutosh\\OneDrive\\Desktop\\fsds task completion'
